# %% [markdown]
# <a href="https://colab.research.google.com/github/zeneto2978/Python-para-Finan-as/blob/main/PYTHON_PARA_FINAN%C3%87AS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PYTHON PARA FINANÇAS

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf

# %% [markdown]
# #BASE DE DADOS DE UMA AÇÃO

# %%
#gol_df = data.DataReader(name = 'GOLL4.SA', data_source='yahoo', start='2015-01-01')
gol_df = yf.download("GOLL4.SA", start='2015-01-01', end='2020-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gol_df
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       GOLL4.SA   GOLL4.SA   GOLL4.SA   GOLL4.SA GOLL4.SA
# Date
# 2015-01-02  14.990000  15.200000  14.610000  14.970000   901900
# 2015-01-05  14.850000  15.010000  14.410000  14.900000  1272500
# 2015-01-06  15.210000  15.210000  14.650000  14.750000  2183500
# 2015-01-07  14.550000  15.330000  14.550000  15.150000  1846900
# 2015-01-08  14.270000  14.650000  14.200000  14.410000  1569500
# ...               ...        ...        ...        ...      ...
# 2019-12-20  35.889999  36.700001  35.470001  36.500000  2146100
# 2019-12-23  36.459999  36.599998  35.970001  35.990002  2173600
# 2019-12-26  36.650002  36.700001  36.320000  36.599998  1588800
# 2019-12-27  36.919998  36.990002  36.360001  36.750000  2680200
# 2019-12-30  36.799999  37.389999  36.450001  36.750000  2628100
#
# [1243 rows x 5 columns]

# %%
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1243 entries, 2015-01-02 to 2019-12-30
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, GOLL4.SA)   1243 non-null   float64
#  1   (High, GOLL4.SA)    1243 non-null   float64
#  2   (Low, GOLL4.SA)     1243 non-null   float64
#  3   (Open, GOLL4.SA)    1243 non-null   float64
#  4   (Volume, GOLL4.SA)  1243 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.3 KB

# %%
gol_df.head()
# Out:
# Price         Close     High      Low     Open   Volume
# Ticker     GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA
# Date
# 2015-01-02    14.99    15.20    14.61    14.97   901900
# 2015-01-05    14.85    15.01    14.41    14.90  1272500
# 2015-01-06    15.21    15.21    14.65    14.75  2183500
# 2015-01-07    14.55    15.33    14.55    15.15  1846900
# 2015-01-08    14.27    14.65    14.20    14.41  1569500

# %%
gol_df.tail()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       GOLL4.SA   GOLL4.SA   GOLL4.SA   GOLL4.SA GOLL4.SA
# Date
# 2019-12-20  35.889999  36.700001  35.470001  36.500000  2146100
# 2019-12-23  36.459999  36.599998  35.970001  35.990002  2173600
# 2019-12-26  36.650002  36.700001  36.320000  36.599998  1588800
# 2019-12-27  36.919998  36.990002  36.360001  36.750000  2680200
# 2019-12-30  36.799999  37.389999  36.450001  36.750000  2628100

# %%
gol_df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker     GOLL4.SA     GOLL4.SA     GOLL4.SA     GOLL4.SA      GOLL4.SA
# count   1243.000000  1243.000000  1243.000000  1243.000000  1.243000e+03
# mean      13.683041    14.024940    13.368455    13.707554  3.312395e+06
# std       10.228810    10.422167    10.028566    10.227482  2.808450e+06
# min        1.160000     1.180000     1.130000     1.160000  0.000000e+00
# 25%        5.880000     6.175000     5.735000     5.950000  1.631950e+06
# 50%       10.260000    10.560000    10.010000    10.250000  2.587900e+06
# 75%       19.875000    20.389999    19.400000    19.780000  4.138250e+06
# max       43.790001    44.619999    41.310001    43.669998  4.287490e+07

# %%
gol_df[gol_df[('Close', 'GOLL4.SA')] >= 43.79]
# Out:
# Price           Close       High      Low     Open   Volume
# Ticker       GOLL4.SA   GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA
# Date
# 2019-08-01  43.790001  44.619999    41.25    41.25  6664200

# %%
gol_df[(gol_df[('Close', 'GOLL4.SA')] >= 1.15) & (gol_df[('Close', 'GOLL4.SA')] <= 1.16)]
# Out:
# Price         Close     High      Low     Open   Volume
# Ticker     GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA
# Date
# 2016-01-22     1.16     1.26     1.14      1.2  3830600

# %%
gol_df.to_csv('gol.csv')

# %%
gol_df2 = pd.read_csv('/content/gol.csv')

# %%
gol_df2
# Out:
#            Price               Close                High                 Low  \
# 0         Ticker            GOLL4.SA            GOLL4.SA            GOLL4.SA
# 1           Date                 NaN                 NaN                 NaN
# 2     2015-01-02  14.989999771118164  15.199999809265137  14.609999656677246
# 3     2015-01-05  14.850000381469727  15.010000228881836   14.40999984741211
# 4     2015-01-06  15.210000038146973  15.210000038146973  14.649999618530273
# ...          ...                 ...                 ...                 ...
# 1240  2019-12-20   35.88999938964844   36.70000076293945  35.470001220703125
# 1241  2019-12-23  36.459999084472656  36.599998474121094  35.970001220703125
# 1242  2019-12-26  36.650001525878906   36.70000076293945   36.31999969482422
# 1243  2019-12-27   36.91999816894531    36.9900016784668   36.36000061035156
# 1244  2019-12-30   36.79999923706055   37.38999938964844   36.45000076293945
#
#                     Open    Volume
# 0               GOLL4.SA  GOLL4.SA
# 1                    NaN       NaN
# 2     14.970000267028809    901900
# 3     14.899999618530273   1272500
# 4                  14.75   2183500
# ...                  ...       ...
# 1240                36.5   2146100
# 1241    35.9900016784668   2173600
# 1242  36.599998474121094   1588800
# 1243               36.75   2680200
# 1244               36.75   2628100
#
# [1245 rows x 6 columns]

# %% [markdown]
# # BASES DE DADOS COM MAIS AÇÕES
# #### . BOVA11: https://www.sunoresearch.com.br/artigos/bova11/

# %%
acoes = ['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()
for acao in acoes:
  #acoes_df[acao] = data.DataReader(acao, data_source='yahoo', start='2015-01-01')['Close']
  acoes_df[acao] = yf.download(acao, start='2015-01-01')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#             GOLL4.SA   CVCB3.SA   WEGE3.SA  MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2015-01-02     14.99  11.164606   4.988705  2.058074  10.155537   47.259998
# 2015-01-05     14.85  11.017706   5.022719  2.096750   9.843493   46.320000
# 2015-01-06     15.21  10.870801   4.948211  2.069124   9.227921   46.580002
# 2015-01-07     14.55  10.775316   4.891522  2.138187   9.162674   48.150002
# 2015-01-08     14.27  10.393368   4.974125  2.121612   9.375430   48.509998
# ...              ...        ...        ...       ...        ...         ...
# 2025-02-10      1.50   1.860000  54.209999  7.260000  33.889999  122.550003
# 2025-02-11      1.51   1.940000  53.110001  7.270000  34.000000  123.449997
# 2025-02-12      1.48   1.830000  52.700001  7.090000  33.049999  121.250000
# 2025-02-13      1.49   1.850000  52.470001  7.010000  33.959999  121.680000
# 2025-02-14      1.51   1.980000  53.799999  7.380000  34.400002  124.870003
#
# [2519 rows x 6 columns]

# %%
acoes_df = acoes_df.rename(columns={'GOLL4.SA': 'GOL', 'CVCB3.SA': 'CVC', 'WEGE3.SA': 'WEGE',
                                    'MGLU3.SA': 'MGLU', 'TOTS3.SA': 'TOTS', 'BOVA11.SA': 'BOVA'})

# %%
acoes_df
# Out:
#               GOL        CVC       WEGE      MGLU       TOTS        BOVA
# Date
# 2015-01-02  14.99  11.164606   4.988705  2.058074  10.155537   47.259998
# 2015-01-05  14.85  11.017706   5.022719  2.096750   9.843493   46.320000
# 2015-01-06  15.21  10.870801   4.948211  2.069124   9.227921   46.580002
# 2015-01-07  14.55  10.775316   4.891522  2.138187   9.162674   48.150002
# 2015-01-08  14.27  10.393368   4.974125  2.121612   9.375430   48.509998
# ...           ...        ...        ...       ...        ...         ...
# 2025-02-10   1.50   1.860000  54.209999  7.260000  33.889999  122.550003
# 2025-02-11   1.51   1.940000  53.110001  7.270000  34.000000  123.449997
# 2025-02-12   1.48   1.830000  52.700001  7.090000  33.049999  121.250000
# 2025-02-13   1.49   1.850000  52.470001  7.010000  33.959999  121.680000
# 2025-02-14   1.51   1.980000  53.799999  7.380000  34.400002  124.870003
#
# [2519 rows x 6 columns]

# %%
acoes_df.isnull()
# Out:
#               GOL    CVC   WEGE   MGLU   TOTS   BOVA
# Date
# 2015-01-02  False  False  False  False  False  False
# 2015-01-05  False  False  False  False  False  False
# 2015-01-06  False  False  False  False  False  False
# 2015-01-07  False  False  False  False  False  False
# 2015-01-08  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...
# 2025-02-10  False  False  False  False  False  False
# 2025-02-11  False  False  False  False  False  False
# 2025-02-12  False  False  False  False  False  False
# 2025-02-13  False  False  False  False  False  False
# 2025-02-14  False  False  False  False  False  False
#
# [2519 rows x 6 columns]

# %%
acoes_df.isnull().sum()
# comando para visualizar dados nulos/ausentes
# Out:
# GOL      0
# CVC      0
# WEGE     0
# MGLU     0
# TOTS     0
# BOVA    27
# dtype: int64

# %%
acoes_df.shape
# Out:
# (2519, 6)

# %%
acoes_df.dropna(inplace=True)
# comando para apagar registros nulos/ausentes

# %%
acoes_df.shape
# Out:
# (2492, 6)

# %%
acoes_df.isnull().sum()
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.to_csv('acoes.csv')

# %%
acoes_df.columns[1:]
# Out:
# Index(['CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
acoes_df.describe()
# Out:
#                GOL          CVC         WEGE         MGLU         TOTS  \
# count  2492.000000  2492.000000  2492.000000  2492.000000  2492.000000
# mean     12.999434    18.485571    21.351985    54.165538    19.353090
# std       9.467865    14.115283    15.409941    66.213958     9.552083
# min       0.980000     1.380000     4.284400     0.279106     6.457615
# 25%       6.237500     6.527281     6.595463     8.481678     9.420963
# 50%      10.225000    14.989857    17.204501    28.049189    19.612712
# 75%      19.072500    27.481258    35.031343    62.853729    28.111171
# max      43.790001    52.870266    58.465912   256.293274    38.656746
#
#               BOVA
# count  2492.000000
# mean     89.491304
# std      26.273876
# min      36.450001
# 25%      64.544998
# 50%      96.570000
# 75%     111.370001
# max     133.619995

# %% [markdown]
# # GRÁFICOS HISTOGRAMAS

# %%
sns.histplot(acoes_df['GOL']);

# sns.histplot(acoes_df['GOL'], bins=5);
# sns.histplot(acoes_df['GOL'], bins=10);

# bins é para divisão das faixas (número de faixas)

# %%
len(acoes_df.columns)
# Out:
# 6

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.histplot(acoes_df[acoes_df.columns[i]], kde = True)
  plt.title(acoes_df.columns[i])

# %%
acoes_df['GOL'].describe()
# Out:
# count    2492.000000
# mean       12.999434
# std         9.467865
# min         0.980000
# 25%         6.237500
# 50%        10.225000
# 75%        19.072500
# max        43.790001
# Name: GOL, dtype: float64

# %%
sns.boxplot(x = acoes_df['GOL']);

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.boxplot(x = acoes_df[acoes_df.columns[i]])
  plt.title(acoes_df.columns[i])

# %%
acoes_df.plot(figsize = (15,7), title = 'Histórico do preço das ações');

# %%
acoes_df
# Out:
#               GOL        CVC       WEGE      MGLU       TOTS        BOVA
# Date
# 2015-01-02  14.99  11.164606   4.988705  2.058074  10.155537   47.259998
# 2015-01-05  14.85  11.017706   5.022719  2.096750   9.843493   46.320000
# 2015-01-06  15.21  10.870801   4.948211  2.069124   9.227921   46.580002
# 2015-01-07  14.55  10.775316   4.891522  2.138187   9.162674   48.150002
# 2015-01-08  14.27  10.393368   4.974125  2.121612   9.375430   48.509998
# ...           ...        ...        ...       ...        ...         ...
# 2025-02-10   1.50   1.860000  54.209999  7.260000  33.889999  122.550003
# 2025-02-11   1.51   1.940000  53.110001  7.270000  34.000000  123.449997
# 2025-02-12   1.48   1.830000  52.700001  7.090000  33.049999  121.250000
# 2025-02-13   1.49   1.850000  52.470001  7.010000  33.959999  121.680000
# 2025-02-14   1.51   1.980000  53.799999  7.380000  34.400002  124.870003
#
# [2492 rows x 6 columns]

# %%
acoes_df_normalizado = acoes_df.copy()
for i in acoes_df_normalizado.columns[1:]:
  acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]
# Out:
# <ipython-input-36-41f87948e692>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]

# %%
acoes_df_normalizado
# Out:
#               GOL       CVC       WEGE      MGLU      TOTS      BOVA
# Date
# 2015-01-02  14.99  1.000000   1.000000  1.000000  1.000000  1.000000
# 2015-01-05  14.85  0.986842   1.006818  1.018792  0.969274  0.980110
# 2015-01-06  15.21  0.973684   0.991883  1.005369  0.908659  0.985612
# 2015-01-07  14.55  0.965132   0.980519  1.038927  0.902234  1.018832
# 2015-01-08  14.27  0.930921   0.997077  1.030873  0.923184  1.026449
# ...           ...       ...        ...       ...       ...       ...
# 2025-02-10   1.50  0.166598  10.866548  3.527570  3.337096  2.593102
# 2025-02-11   1.51  0.173763  10.646050  3.532429  3.347927  2.612146
# 2025-02-12   1.48  0.163911  10.563865  3.444969  3.254382  2.565595
# 2025-02-13   1.49  0.165702  10.517761  3.406098  3.343989  2.574693
# 2025-02-14   1.51  0.177346  10.784362  3.585877  3.387315  2.642192
#
# [2492 rows x 6 columns]

# %%
acoes_df_normalizado.plot(figsize = (15,7), title = 'Histórico do preço das ações - Normalizado');

# %% [markdown]
# #GRÁFICO DINÂMICO DAS AÇÕES

# %%
acoes_df = acoes_df.reset_index()
# TIVE QUE USAR ESSE RECURSO PARA RESETAR AS COLUNAS E INSERIR O "DATE"

# %%
print(acoes_df.columns)
# Out:
# Index(['Date', 'GOL', 'CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
figura = px.line(title = 'Histórico do preço das ações')
for i in acoes_df.columns[1:]:
  figura.add_scatter(x = acoes_df['Date'], y = acoes_df[i], name = i)
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="0d5aa6d6-39ee-40e5-8d98-f543005e029d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0d5aa6d6-39ee-40e5-8d98-f543005e029d")) {                    Plotly.newPlot(                        "0d5aa6d6-39ee-40e5-8d98-f543005e029d",                        [{"hovertemplate":"\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"name":"GOL","x":["2015-01-02T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-