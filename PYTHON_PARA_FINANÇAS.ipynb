# %% [markdown]
# <a href="https://colab.research.google.com/github/zeneto2978/Python-para-Finan-as/blob/main/PYTHON_PARA_FINAN%C3%87AS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# se necessário usar o código abaixo para atualizar o yfinance

# %% [markdown]
# # PYTHON PARA FINANÇAS

# %%
pip install --upgrade yfinance

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf

# %% [markdown]
# #BASE DE DADOS DE UMA AÇÃO

# %%
#gol_df = data.DataReader(name = 'GOLL4.SA', data_source='yahoo', start='2015-01-01')
gol_df = yf.download("GOLL4.SA", start='2020-01-01', end='2025-02-18')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
gol_df
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       GOLL4.SA   GOLL4.SA   GOLL4.SA   GOLL4.SA GOLL4.SA
# Date
# 2020-01-02  37.169998  37.240002  36.599998  36.680000  2319400
# 2020-01-03  35.900002  36.450001  35.590000  36.000000  4342600
# 2020-01-06  34.250000  35.500000  34.200001  35.500000  6271300
# 2020-01-07  34.450001  34.840000  34.209999  34.650002  3310300
# 2020-01-08  35.810001  36.299999  34.610001  34.610001  7156200
# ...               ...        ...        ...        ...      ...
# 2025-02-11   1.510000   1.520000   1.490000   1.490000  2247600
# 2025-02-12   1.480000   1.500000   1.460000   1.490000  2734800
# 2025-02-13   1.490000   1.500000   1.470000   1.480000  2960000
# 2025-02-14   1.510000   1.530000   1.480000   1.490000  4808100
# 2025-02-17   1.510000   1.550000   1.510000   1.510000  2689700
#
# [1277 rows x 5 columns]

# %%
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1277 entries, 2020-01-02 to 2025-02-17
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, GOLL4.SA)   1277 non-null   float64
#  1   (High, GOLL4.SA)    1277 non-null   float64
#  2   (Low, GOLL4.SA)     1277 non-null   float64
#  3   (Open, GOLL4.SA)    1277 non-null   float64
#  4   (Volume, GOLL4.SA)  1277 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.9 KB

# %%
gol_df.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       GOLL4.SA   GOLL4.SA   GOLL4.SA   GOLL4.SA GOLL4.SA
# Date
# 2020-01-02  37.169998  37.240002  36.599998  36.680000  2319400
# 2020-01-03  35.900002  36.450001  35.590000  36.000000  4342600
# 2020-01-06  34.250000  35.500000  34.200001  35.500000  6271300
# 2020-01-07  34.450001  34.840000  34.209999  34.650002  3310300
# 2020-01-08  35.810001  36.299999  34.610001  34.610001  7156200

# %%
gol_df.tail()
# Out:
# Price         Close     High      Low     Open   Volume
# Ticker     GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA
# Date
# 2025-02-11     1.51     1.52     1.49     1.49  2247600
# 2025-02-12     1.48     1.50     1.46     1.49  2734800
# 2025-02-13     1.49     1.50     1.47     1.48  2960000
# 2025-02-14     1.51     1.53     1.48     1.49  4808100
# 2025-02-17     1.51     1.55     1.51     1.51  2689700

# %%
gol_df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker     GOLL4.SA     GOLL4.SA     GOLL4.SA     GOLL4.SA      GOLL4.SA
# count   1277.000000  1277.000000  1277.000000  1277.000000  1.277000e+03
# mean      12.489452    12.868363    12.185184    12.533156  9.920066e+06
# std        8.659798     8.861449     8.490043     8.684450  6.685490e+06
# min        0.980000     1.000000     0.960000     0.990000  8.729000e+05
# 25%        6.630000     6.870000     6.440000     6.650000  5.741500e+06
# 50%       10.410000    10.800000    10.030000    10.460000  8.415900e+06
# 75%       18.959999    19.660000    18.430000    18.990000  1.219300e+07
# max       39.049999    39.259998    37.549999    39.209999  7.499800e+07

# %%
gol_df[gol_df[('Close', 'GOLL4.SA')] >= 43.79]
# Out:
# Empty DataFrame
# Columns: [(Close, GOLL4.SA), (High, GOLL4.SA), (Low, GOLL4.SA), (Open, GOLL4.SA), (Volume, GOLL4.SA)]
# Index: []

# %%
gol_df[(gol_df[('Close', 'GOLL4.SA')] >= 1.15) & (gol_df[('Close', 'GOLL4.SA')] <= 1.16)]
# Out:
# Price         Close     High      Low     Open   Volume
# Ticker     GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA GOLL4.SA
# Date
# 2024-07-26     1.16     1.16     1.12     1.13  2676100

# %%
gol_df.to_csv('gol.csv')

# %%
gol_df2 = pd.read_csv('/content/gol.csv')

# %%
gol_df2
# Out:
#            Price               Close                High                 Low  \
# 0         Ticker            GOLL4.SA            GOLL4.SA            GOLL4.SA
# 1           Date                 NaN                 NaN                 NaN
# 2     2020-01-02   37.16999816894531    37.2400016784668  36.599998474121094
# 3     2020-01-03  35.900001525878906   36.45000076293945   35.59000015258789
# 4     2020-01-06               34.25                35.5   34.20000076293945
# ...          ...                 ...                 ...                 ...
# 1274  2025-02-11  1.5099999904632568  1.5199999809265137  1.4900000095367432
# 1275  2025-02-12  1.4800000190734863                 1.5  1.4600000381469727
# 1276  2025-02-13  1.4900000095367432                 1.5  1.4700000286102295
# 1277  2025-02-14  1.5099999904632568  1.5299999713897705  1.4800000190734863
# 1278  2025-02-17  1.5099999904632568  1.5499999523162842  1.5099999904632568
#
#                     Open    Volume
# ...

# %% [markdown]
# # BASES DE DADOS COM MAIS AÇÕES
# #### . BOVA11: https://www.sunoresearch.com.br/artigos/bova11/

# %%
acoes = ['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()
for acao in acoes:
  #acoes_df[acao] = data.DataReader(acao, data_source='yahoo', start='2015-01-01')['Close']
  acoes_df[acao] = yf.download(acao, start='2020-01-01')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#              GOLL4.SA   CVCB3.SA   WEGE3.SA    MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2020-01-02  37.169998  36.849518  16.412878  115.015053  21.646765  114.239998
# 2020-01-03  35.900002  36.429180  16.203287  113.989174  22.106939  113.800003
# 2020-01-06  34.250000  36.115990  16.245199  114.082436  21.602943  112.589996
# 2020-01-07  34.450001  36.594017  16.370951  113.756027  21.693727  112.239998
# 2020-01-08  35.810001  36.544567  15.751516  117.253342  21.402597  111.949997
# ...               ...        ...        ...         ...        ...         ...
# 2025-02-13   1.490000   1.850000  52.470001    7.010000  33.959999  121.680000
# 2025-02-14   1.510000   1.980000  53.799999    7.380000  34.400002  124.870003
# 2025-02-17   1.510000   2.070000  52.450001    7.960000  34.509998  125.250000
# 2025-02-18   1.500000   2.040000  52.889999    7.680000  34.299999  125.300003
# 2025-02-19   1.450000   1.850000  52.209999    7.450000  34.040001  124.199997
#
# ...

# %%
acoes_df = acoes_df.rename(columns={'GOLL4.SA': 'GOL', 'CVCB3.SA': 'CVC', 'WEGE3.SA': 'WEGE',
                                    'MGLU3.SA': 'MGLU', 'TOTS3.SA': 'TOTS', 'BOVA11.SA': 'BOVA'})

# %%
acoes_df
# Out:
#                   GOL        CVC       WEGE        MGLU       TOTS        BOVA
# Date
# 2020-01-02  37.169998  36.849518  16.412878  115.015053  21.646765  114.239998
# 2020-01-03  35.900002  36.429180  16.203287  113.989174  22.106939  113.800003
# 2020-01-06  34.250000  36.115990  16.245199  114.082436  21.602943  112.589996
# 2020-01-07  34.450001  36.594017  16.370951  113.756027  21.693727  112.239998
# 2020-01-08  35.810001  36.544567  15.751516  117.253342  21.402597  111.949997
# ...               ...        ...        ...         ...        ...         ...
# 2025-02-13   1.490000   1.850000  52.470001    7.010000  33.959999  121.680000
# 2025-02-14   1.510000   1.980000  53.799999    7.380000  34.400002  124.870003
# 2025-02-17   1.510000   2.070000  52.450001    7.960000  34.509998  125.250000
# 2025-02-18   1.500000   2.040000  52.889999    7.680000  34.299999  125.300003
# 2025-02-19   1.450000   1.850000  52.209999    7.450000  34.040001  124.199997
#
# ...

# %%
acoes_df.isnull()
# Out:
#               GOL    CVC   WEGE   MGLU   TOTS   BOVA
# Date
# 2020-01-02  False  False  False  False  False  False
# 2020-01-03  False  False  False  False  False  False
# 2020-01-06  False  False  False  False  False  False
# 2020-01-07  False  False  False  False  False  False
# 2020-01-08  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...
# 2025-02-13  False  False  False  False  False  False
# 2025-02-14  False  False  False  False  False  False
# 2025-02-17  False  False  False  False  False  False
# 2025-02-18  False  False  False  False  False  False
# 2025-02-19  False  False  False  False  False  False
#
# [1279 rows x 6 columns]

# %%
acoes_df.isnull().sum()
# comando para visualizar dados nulos/ausentes
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.shape
# Out:
# (1279, 6)

# %%
acoes_df.dropna(inplace=True)
# comando para apagar registros nulos/ausentes

# %%
acoes_df.shape
# Out:
# (1279, 6)

# %%
acoes_df.isnull().sum()
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.to_csv('acoes.csv')

# %%
acoes_df.columns[1:]
# Out:
# Index(['CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
acoes_df.describe()
# Out:
#                GOL          CVC         WEGE         MGLU         TOTS  \
# count  1279.000000  1279.000000  1279.000000  1279.000000  1279.000000
# mean     12.472228     9.645282    34.960633    82.693879    28.020027
# std       8.663965     7.715471     9.070763    77.987333     4.099179
# min       0.980000     1.380000    12.369955     5.810000    13.179015
# 25%       6.615000     2.900000    30.384581    20.441791    26.161766
# 50%      10.400000     6.766596    34.699688    39.844772    28.042503
# 75%      18.955000    15.728455    38.324226   150.228676    30.225760
# max      39.049999    36.849518    58.465912   256.293274    38.656742
#
#               BOVA
# count  1279.000000
# mean    110.002768
# std      12.545718
# min      61.139999
# 25%     102.485001
# 50%     110.889999
# 75%     119.599998
# max     133.619995

# %% [markdown]
# # GRÁFICOS HISTOGRAMAS

# %%
sns.histplot(acoes_df['GOL']);

# sns.histplot(acoes_df['GOL'], bins=5);
# sns.histplot(acoes_df['GOL'], bins=10);

# bins é para divisão das faixas (número de faixas)

# %%
len(acoes_df.columns)
# Out:
# 6

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.histplot(acoes_df[acoes_df.columns[i]], kde = True)
  plt.title(acoes_df.columns[i])

# %%
acoes_df['GOL'].describe()
# Out:
# count    1279.000000
# mean       12.472228
# std         8.663965
# min         0.980000
# 25%         6.615000
# 50%        10.400000
# 75%        18.955000
# max        39.049999
# Name: GOL, dtype: float64

# %%
sns.boxplot(x = acoes_df['GOL']);

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.boxplot(x = acoes_df[acoes_df.columns[i]])
  plt.title(acoes_df.columns[i])

# %%
acoes_df.plot(figsize = (15,7), title = 'Histórico do preço das ações');

# %%
acoes_df
# Out:
#                   GOL        CVC       WEGE        MGLU       TOTS        BOVA
# Date
# 2020-01-02  37.169998  36.849518  16.412878  115.015053  21.646765  114.239998
# 2020-01-03  35.900002  36.429180  16.203287  113.989174  22.106939  113.800003
# 2020-01-06  34.250000  36.115990  16.245199  114.082436  21.602943  112.589996
# 2020-01-07  34.450001  36.594017  16.370951  113.756027  21.693727  112.239998
# 2020-01-08  35.810001  36.544567  15.751516  117.253342  21.402597  111.949997
# ...               ...        ...        ...         ...        ...         ...
# 2025-02-13   1.490000   1.850000  52.470001    7.010000  33.959999  121.680000
# 2025-02-14   1.510000   1.980000  53.799999    7.380000  34.400002  124.870003
# 2025-02-17   1.510000   2.070000  52.450001    7.960000  34.509998  125.250000
# 2025-02-18   1.500000   2.040000  52.889999    7.680000  34.299999  125.300003
# 2025-02-19   1.450000   1.850000  52.209999    7.450000  34.040001  124.199997
#
# ...

# %%
acoes_df_normalizado = acoes_df.copy()
for i in acoes_df_normalizado.columns[1:]:
  acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]
# Out:
# <ipython-input-36-41f87948e692>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]

# %%
acoes_df_normalizado
# Out:
#                   GOL       CVC      WEGE      MGLU      TOTS      BOVA
# Date
# 2020-01-02  37.169998  1.000000  1.000000  1.000000  1.000000  1.000000
# 2020-01-03  35.900002  0.988593  0.987230  0.991080  1.021258  0.996149
# 2020-01-06  34.250000  0.980094  0.989784  0.991891  0.997976  0.985557
# 2020-01-07  34.450001  0.993066  0.997445  0.989053  1.002170  0.982493
# 2020-01-08  35.810001  0.991724  0.959705  1.019461  0.988720  0.979954
# ...               ...       ...       ...       ...       ...       ...
# 2025-02-13   1.490000  0.050204  3.196880  0.060949  1.568826  1.065126
# 2025-02-14   1.510000  0.053732  3.277914  0.064166  1.589152  1.093050
# 2025-02-17   1.510000  0.056174  3.195661  0.069208  1.594234  1.096376
# 2025-02-18   1.500000  0.055360  3.222470  0.066774  1.584532  1.096814
# 2025-02-19   1.450000  0.050204  3.181039  0.064774  1.572521  1.087185
#
# [1279 rows x 6 columns]

# %%
acoes_df_normalizado.plot(figsize = (15,7), title = 'Histórico do preço das ações - Normalizado');

# %% [markdown]
# #GRÁFICO DINÂMICO DAS AÇÕES

# %%
acoes_df = acoes_df.reset_index()
# TIVE QUE USAR ESSE RECURSO PARA RESETAR AS COLUNAS E INSERIR O "DATE"

# %%
print(acoes_df.columns)
# Out:
# Index(['Date', 'GOL', 'CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
figura = px.line(title = 'Histórico do preço das ações')
for i in acoes_df.columns[1:]:
  figura.add_scatter(x = acoes_df['Date'], y = acoes_df[i], name = i)
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
acoes_df_normalizado = acoes_df_normalizado.reset_index()
# TIVE QUE USAR ESSE RECURSO PARA RESETAR AS COLUNAS E INSERIR O "DATE"

# %%
figura = px.line(title = 'Histórico do preço das ações - Normalizado')
for i in acoes_df_normalizado.columns[1:]:
  figura.add_scatter(x = acoes_df_normalizado['Date'], y = acoes_df_normalizado[i], name = i)
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
